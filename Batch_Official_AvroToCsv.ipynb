# %%
# !pip install --user avro
# Out:
# Requirement already satisfied: avro in /home/jovyan/.local/lib/python3.8/site-packages (1.12.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import sys
print(sys.path)
# Out:
# ['/usr/lib/python38.zip', '/usr/lib/python3.8', '/usr/lib/python3.8/lib-dynload', '', '/home/jovyan/.local/lib/python3.8/site-packages', '/usr/local/lib/python3.8/dist-packages', '/usr/lib/python3/dist-packages']

# %%
import sys
sys.path.append('/home/jovyan/.local/lib/python3.8/site-packages')

from avro.datafile import DataFileReader
from avro.io import DatumReader
import json
import csv
import os
import time

# Base directory for participant data
base_dir = "Participant data (participant id,time)"
output_dir_base = "Processed_Output"

# Count total files for progress reporting
total_files = sum(len(files) for _, _, files in os.walk(base_dir) if files)
processed_files = 0

# Traverse through the directory structure and process all avro files
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".avro"):
            avro_file_path = os.path.join(root, file)
            
            # Print progress
            processed_files += 1
            print(f"[{processed_files}/{total_files}] Processing {avro_file_path}...")

            # Generate the output directory structure
            participant_id = root.split(os.sep)[1]  # Get participant ID from path
            date_folder = root.split(os.sep)[2]  # Get date folder from path
            output_dir = os.path.join(output_dir_base, participant_id, date_folder)
            os.makedirs(output_dir, exist_ok=True)

            try:
                # Process the AVRO file
                with DataFileReader(open(avro_file_path, "rb"), DatumReader()) as reader:
                    schema = json.loads(reader.meta.get('avro.schema').decode('utf-8'))
                    data = next(reader)

                    # Function to write CSV data
                    def write_csv(filename, headers, rows):
                        with open(os.path.join(output_dir, filename), 'w', newline='') as f:
                            writer = csv.writer(f)
                            writer.writerow(headers)
                            writer.writerows(rows)

                    # Accelerometer processing
                    acc = data["rawData"]["accelerometer"]
                    timestamp = [round(acc["timestampStart"] + i * (1e6 / acc["samplingFrequency"]))
                                 for i in range(len(acc["x"]))]
                    delta_physical = acc["imuParams"]["physicalMax"] - acc["imuParams"]["physicalMin"]
                    delta_digital = acc["imuParams"]["digitalMax"] - acc["imuParams"]["digitalMin"]
                    x_g = [val * delta_physical / delta_digital for val in acc["x"]]
                    y_g = [val * delta_physical / delta_digital for val in acc["y"]]
                    z_g = [val * delta_physical / delta_digital for val in acc["z"]]
                    write_csv('accelerometer.csv', ["unix_timestamp", "x", "y", "z"],
                              zip(timestamp, x_g, y_g, z_g))

                    # Gyroscope processing
                    gyro = data["rawData"]["gyroscope"]
                    timestamp = [round(gyro["timestampStart"] + i * (1e6 / gyro["samplingFrequency"]))
                                 for i in range(len(gyro["x"]))]
                    delta_physical = gyro["imuParams"]["physicalMax"] - gyro["imuParams"]["physicalMin"]
                    delta_digital = gyro["imuParams"]["digitalMax"] - gyro["imuParams"]["digitalMin"]
                    x_dps = [val * delta_physical / delta_digital for val in gyro["x"]]
                    y_dps = [val * delta_physical / delta_digital for val in gyro["y"]]
                    z_dps = [val * delta_physical / delta_digital for val in gyro["z"]]
                    write_csv('gyroscope.csv', ["unix_timestamp", "x", "y", "z"],
                              zip(timestamp, x_dps, y_dps, z_dps))

                    # EDA processing
                    eda = data["rawData"]["eda"]
                    timestamp = [round(eda["timestampStart"] + i * (1e6 / eda["samplingFrequency"]))
                                 for i in range(len(eda["values"]))]
                    write_csv('eda.csv', ["unix_timestamp", "eda"], zip(timestamp, eda["values"]))

                    # Temperature processing
                    tmp = data["rawData"]["temperature"]
                    timestamp = [round(tmp["timestampStart"] + i * (1e6 / tmp["samplingFrequency"]))
                                 for i in range(len(tmp["values"]))]
                    write_csv('temperature.csv', ["unix_timestamp", "temperature"], zip(timestamp, tmp["values"]))

                    # Tags processing
                    tags = data["rawData"]["tags"]
                    write_csv('tags.csv', ["tags_timestamp"], [[tag] for tag in tags["tagsTimeMicros"]])

                    # BVP processing
                    bvp = data["rawData"]["bvp"]
                    timestamp = [round(bvp["timestampStart"] + i * (1e6 / bvp["samplingFrequency"]))
                                 for i in range(len(bvp["values"]))]
                    write_csv('bvp.csv', ["unix_timestamp", "bvp"], zip(timestamp, bvp["values"]))

                    # Systolic peaks processing
                    sps = data["rawData"]["systolicPeaks"]
                    write_csv('systolic_peaks.csv', ["systolic_peak_timestamp"], [[sp] for sp in sps["peaksTimeNanos"]])

                    # Steps processing
                    steps = data["rawData"]["steps"]
                    timestamp = [round(steps["timestampStart"] + i * (1e6 / steps["samplingFrequency"]))
                                 for i in range(len(steps["values"]))]
                    write_csv('steps.csv', ["unix_timestamp", "steps"], zip(timestamp, steps["values"]))

                print(f"Finished processing {avro_file_path}, output saved to {output_dir}")

            except Exception as e:
                print(f"Error processing {avro_file_path}: {e}")

            # Optional: Simulate processing time for visibility (remove or adjust for actual use)
            time.sleep(0.5)

# %%
from avro.datafile import DataFileReader
from avro.io import DatumReader
import json
import csv
import os

# Base directory for participant data
base_dir = "Participant data (participant id,time)"
output_dir_base = "Processed_Output"
log_file = "processed_files.log"

# Load the list of already processed files
if os.path.exists(log_file):
    with open(log_file, 'r') as log:
        processed_files = set(log.read().splitlines())
else:
    processed_files = set()

# Traverse through the directory structure and process all avro files
for root, dirs, files in os.walk(base_dir):
    for file in files:
        if file.endswith(".avro"):
            avro_file_path = os.path.join(root, file)

            # Skip if this file has already been processed
            if avro_file_path in processed_files:
                print(f"Skipping already processed file: {avro_file_path}")
                continue

            # Generate the output directory structure
            participant_id = root.split(os.sep)[1]  # Get participant ID from path
            date_folder = root.split(os.sep)[2]  # Get date folder from path
            output_dir = os.path.join(output_dir_base, participant_id, date_folder)
            os.makedirs(output_dir, exist_ok=True)

            try:
                # Process the AVRO file
                with DataFileReader(open(avro_file_path, "rb"), DatumReader()) as reader:
                    schema = json.loads(reader.meta.get('avro.schema').decode('utf-8'))
                    data = next(reader)

                    # Function to write CSV data
                    def write_csv(filename, headers, rows):
                        with open(os.path.join(output_dir, filename), 'a', newline='') as f:
                            writer = csv.writer(f)
                            if os.stat(os.path.join(output_dir, filename)).st_size == 0:  # Check if file is empty
                                writer.writerow(headers)  # Write headers only if the file is empty
                            writer.writerows(rows)



                    # Accelerometer processing
                    acc = data["rawData"]["accelerometer"]
                    timestamp = [round(acc["timestampStart"] + i * (1e6 / acc["samplingFrequency"]))
                                 for i in range(len(acc["x"]))]
                    delta_physical = acc["imuParams"]["physicalMax"] - acc["imuParams"]["physicalMin"]
                    delta_digital = acc["imuParams"]["digitalMax"] - acc["imuParams"]["digitalMin"]
                    x_g = [val * delta_physical / delta_digital for val in acc["x"]]
                    y_g = [val * delta_physical / delta_digital for val in acc["y"]]
                    z_g = [val * delta_physical / delta_digital for val in acc["z"]]
                    write_csv('accelerometer.csv', ["unix_timestamp", "x", "y", "z"],
                              zip(timestamp, x_g, y_g, z_g))

                    # Gyroscope processing
                    gyro = data["rawData"]["gyroscope"]
                    timestamp = [round(gyro["timestampStart"] + i * (1e6 / gyro["samplingFrequency"]))
                                 for i in range(len(gyro["x"]))]
                    delta_physical = gyro["imuParams"]["physicalMax"] - gyro["imuParams"]["physicalMin"]
                    delta_digital = gyro["imuParams"]["digitalMax"] - gyro["imuParams"]["digitalMin"]
                    x_dps = [val * delta_physical / delta_digital for val in gyro["x"]]
                    y_dps = [val * delta_physical / delta_digital for val in gyro["y"]]
                    z_dps = [val * delta_physical / delta_digital for val in gyro["z"]]
                    write_csv('gyroscope.csv', ["unix_timestamp", "x", "y", "z"],
                              zip(timestamp, x_dps, y_dps, z_dps))

                    # EDA processing
                    eda = data["rawData"]["eda"]
                    timestamp = [round(eda["timestampStart"] + i * (1e6 / eda["samplingFrequency"]))
                                 for i in range(len(eda["values"]))]
                    write_csv('eda.csv', ["unix_timestamp", "eda"], zip(timestamp, eda["values"]))

                    # Temperature processing
                    tmp = data["rawData"]["temperature"]
                    timestamp = [round(tmp["timestampStart"] + i * (1e6 / tmp["samplingFrequency"]))
                                 for i in range(len(tmp["values"]))]
                    write_csv('temperature.csv', ["unix_timestamp", "temperature"], zip(timestamp, tmp["values"]))

                    # Tags processing
                    tags = data["rawData"]["tags"]
                    write_csv('tags.csv', ["tags_timestamp"], [[tag] for tag in tags["tagsTimeMicros"]])

                    # BVP processing
                    bvp = data["rawData"]["bvp"]
                    timestamp = [round(bvp["timestampStart"] + i * (1e6 / bvp["samplingFrequency"]))
                                 for i in range(len(bvp["values"]))]
                    write_csv('bvp.csv', ["unix_timestamp", "bvp"], zip(timestamp, bvp["values"]))

                    # Systolic peaks processing
                    sps = data["rawData"]["systolicPeaks"]
                    write_csv('systolic_peaks.csv', ["systolic_peak_timestamp"], [[sp] for sp in sps["peaksTimeNanos"]])

                    # Steps processing
                    steps = data["rawData"]["steps"]
                    timestamp = [round(steps["timestampStart"] + i * (1e6 / steps["samplingFrequency"]))
                                 for i in range(len(steps["values"]))]
                    write_csv('steps.csv', ["unix_timestamp", "steps"], zip(timestamp, steps["values"]))

                # Log the processed file
                with open(log_file, 'a') as log:
                    log.write(avro_file_path + '\n')

                print(f"Processed {avro_file_path} and saved output to {output_dir}")

            except Exception as e:
                print(f"Error processing {avro_file_path}: {e}")
# Out:
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710855484.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710857290.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710859096.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710860901.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710862701.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710864502.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710866300.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710868106.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710869911.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710871713.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710873512.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710875318.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710877121.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710878928.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710880727.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710882531.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710884336.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710886136.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710887941.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710889745.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-19/raw_data/v6/1-1-10_1710891550.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710893357.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710895160.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710896962.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710898760.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710900565.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710902368.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710904164.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710905967.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710907770.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710909577.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710911380.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710913180.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710914986.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710916786.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710918593.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710920392.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710922191.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710923993.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710925796.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710927597.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710929403.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710931205.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710933006.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710934810.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710936610.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710938416.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710940215.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710942016.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710943818.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710945621.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710947426.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710949231.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710951036.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710952838.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710954638.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710956443.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710958239.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710958675.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710960481.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710962286.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710964092.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710965890.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710967698.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710969500.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710971300.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710973105.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710974909.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710976710.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-20/raw_data/v6/1-1-10_1710978517.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710980315.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710982116.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710983922.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710985728.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710987529.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710989327.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710991133.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710992939.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710994736.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710996543.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1710998344.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711000148.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711001951.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711003758.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711005562.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711007368.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711009168.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711010972.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711012770.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711014574.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711016370.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711018176.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711019975.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711021777.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711023582.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711025383.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711027186.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711028984.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711030788.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711032589.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711034389.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711036190.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711037995.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711039797.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711041598.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711043397.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711045196.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711046997.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711048794.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711050598.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711052403.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711054205.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711056011.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711058117.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711059918.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711061722.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711063527.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-21/raw_data/v6/1-1-10_1711065324.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711067128.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711068931.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711070729.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711072532.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711074337.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711076134.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711077932.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711079732.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711081532.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711083330.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711085135.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711086940.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711088737.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711090542.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711092342.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711094143.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711095944.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711097750.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711099549.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711101352.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711103149.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711104953.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711106753.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711108553.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711110356.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711112158.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711113957.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711115764.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711117567.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711119366.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711121164.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711122963.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711124767.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711126570.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711128375.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711130172.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711131976.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711133779.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711135581.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711137383.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711139183.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711140984.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711142785.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711144585.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-22/raw_data/v6/1-1-10_1711146387.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711152142.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711153949.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711155758.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711157560.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711159362.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711161167.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711161778.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711161792.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711163594.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711165398.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711167195.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711169003.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711170802.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711172609.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711174414.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711176218.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711178024.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711179829.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711181625.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711183430.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711185231.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711187031.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711188837.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711190638.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711192441.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711194245.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711196046.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711197853.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711199652.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711201455.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711203264.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711205068.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711206870.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711208672.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711210473.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711212270.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711214072.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711215876.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711217683.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711219485.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711221293.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711223095.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711224896.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711226700.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711228502.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711230306.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711232105.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711233913.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711235710.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-23/raw_data/v6/1-1-10_1711237512.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711239312.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711241111.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711242912.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711244711.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711246514.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711248313.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711250118.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711251920.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711253722.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711255522.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711257322.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711259128.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711260925.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711262725.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711264526.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711266332.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711268137.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711269937.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711271740.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711273546.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711275348.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711277152.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711278954.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711280752.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711282558.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711284356.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711286155.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711287963.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711289760.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711291563.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711293360.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711295169.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711296971.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711298776.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711300582.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711302383.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711304184.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711305982.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711307780.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711309586.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711311387.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711313190.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711314991.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711316790.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711318597.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711320397.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711322195.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-24/raw_data/v6/1-1-10_1711323998.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711325797.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711329580.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711331384.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711333182.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711334982.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711336782.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711338589.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711340323.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711342128.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711343933.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711345739.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711347540.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711349344.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711351148.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711352948.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711354754.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711356553.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711358351.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711360158.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711361959.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711363762.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711365566.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711367369.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711369171.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711370977.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711372782.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711374582.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711376382.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711378181.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711379987.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711381791.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711383597.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711385401.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711387202.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711389007.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711390806.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711392606.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711394401.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711396207.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711398009.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711399806.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711401610.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711403407.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711405213.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711407015.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711408818.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-25/raw_data/v6/1-1-10_1711410617.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711412416.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711414224.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711416024.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711417826.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711419627.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711421427.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711423234.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711425036.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711426834.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711428631.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711430439.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711432240.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711434044.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711435848.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711437651.avro
# Skipping already processed file: Participant data (participant id,time)/10-3YK3H151PR/2024-03-26/raw_data/v6/1-1-10_1711439457.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711446267.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711448068.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711449867.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711451669.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711453472.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711455278.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711457080.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711458878.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711460678.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711462485.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711464287.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711466088.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711467888.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711469688.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711471492.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711473289.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711475095.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711476896.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711478698.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711480505.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711482308.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711484107.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711485911.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711487709.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711489511.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711491308.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711493110.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711494911.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-26/raw_data/v6/1-1-11_1711496711.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-27/raw_data/v6/1-1-11_1711498514.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-27/raw_data/v6/1-1-11_1711500313.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-27/raw_data/v6/1-1-11_1711502112.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-27/raw_data/v6/1-1-11_1711503912.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-27/raw_data/v6/1-1-11_1711505712.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-27/raw_data/v6/1-1-11_1711507511.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-27/raw_data/v6/1-1-11_1711509316.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-27/raw_data/v6/1-1-11_1711511117.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-27/raw_data/v6/1-1-11_1711512919.avro
# Skipping already processed file: Participant data (participant id,time)/11-3YK3J151H3/2024-03-27/raw_data/v6/1-1-11_1711514722.avro
# ...
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-27/raw_data/v6/1-1-33_1711583847.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-27
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711585646.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711587442.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711589244.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711591047.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711592854.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711594657.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711596457.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711598264.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711600068.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711601868.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711603671.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711605472.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711607271.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711609078.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711610877.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711612682.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711614484.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711616288.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711618089.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711619886.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711621687.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711623490.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711625294.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711627099.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711628899.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711630699.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711632502.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711634301.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711636107.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711637911.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711639713.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711641518.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711643320.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711645123.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711646925.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711648726.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711650528.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711652333.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711654138.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711655938.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711657742.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711660227.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711660247.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711662049.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711663853.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711665657.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711667460.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-28/raw_data/v6/1-1-33_1711669264.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-28
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711671067.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711672865.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711674671.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711676471.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711678273.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711680075.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711681875.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711683675.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711685478.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711686641.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711688443.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711690250.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711692055.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711693854.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711695654.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711697457.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711699258.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711701060.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711702859.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711704668.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711706469.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711708269.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711709197.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711711002.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711712803.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711714606.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711716410.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711718207.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711720007.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711721807.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711723611.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711723724.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711725349.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711725562.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711727369.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711729172.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711730976.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711731583.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711731598.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711733401.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711734118.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711735927.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711737731.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
# Processed Participant data (participant id,time)/33-3YK3H151KR/2024-03-29/raw_data/v6/1-1-33_1711739531.avro and saved output to Processed_Output/33-3YK3H151KR/2024-03-29
