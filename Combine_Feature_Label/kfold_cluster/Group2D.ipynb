# %%
import pandas as pd
import pickle
from sklearn.model_selection import GroupKFold

# ===== Step 1: Load and Inspect the Original Data =====
csv_file = "processed_dataset_with_participant_id.csv"
df = pd.read_csv(csv_file)
print("=== Original Data ===")
print("Total rows:", len(df))
print("Unique participant_ids (raw):", df["participant_id"].unique())
print("Counts per participant:\n", df["participant_id"].value_counts())
print("-" * 50)

# ===== Step 2: Group Data Solely by 'participant_id' =====
grouped_data = []
group_ids = []
# Make sure there are no hidden differences (like leading/trailing spaces)
df["participant_id"] = df["participant_id"].str.strip()

for participant, group in df.groupby("participant_id"):
    print(f"Grouping participant: {participant} with {len(group)} rows")
    grouped_data.append(group)
    group_ids.append(participant)

print("Total groups formed:", len(group_ids))
print("Unique group_ids:", set(group_ids))
print("-" * 50)

# ===== Step 3: Save the Grouped Data =====
grouped_dict = {
    "group_id": group_ids, 
    "data": grouped_data, 
    "columns": grouped_data[0].columns.tolist() if grouped_data else []
}
processed_file = "processed_2d_data_new.pkl"
with open(processed_file, "wb") as f:
    pickle.dump(grouped_dict, f)
print("Grouped data saved to", processed_file)
print("-" * 50)

# ===== Step 4: Check the GroupKFold Splitting =====
# Load back the processed data (for clarity in debugging)
with open(processed_file, "rb") as f:
    grouped_dict = pickle.load(f)

data = grouped_dict["data"]
group_ids = grouped_dict["group_id"]
print("=== Processed Data Info ===")
print("Number of unique participants:", len(set(group_ids)))
print("List of participant IDs:", group_ids)
print("-" * 50)

# Initialize GroupKFold with 5 splits
gkf = GroupKFold(n_splits=5)
fold_indices = []
for fold, (train_idx, test_idx) in enumerate(gkf.split(data, groups=group_ids)):
    train_group_ids = [group_ids[i] for i in train_idx]
    test_group_ids = [group_ids[i] for i in test_idx]
    print(f"Fold {fold+1}:")
    print("  Train indices:", train_idx)
    print("  Test indices:", test_idx)
    print("  Train participant IDs:", train_group_ids)
    print("  Test participant IDs:", test_group_ids)
    print("-" * 30)
    fold_indices.append((train_idx, test_idx))

# ===== Step 5: Save Each Fold and Print Participant IDs =====
for fold, (train_idx, test_idx) in enumerate(gkf.split(data, groups=group_ids)):
    train_data = [data[i] for i in train_idx]
    test_data = [data[i] for i in test_idx]
    
    train_file_path = f"train_2d_fold{fold+1}.pkl"
    test_file_path = f"test_2d_fold{fold+1}.pkl"
    
    train_dict = {
        "data": train_data, 
        "columns": grouped_dict["columns"], 
        "group_ids": [group_ids[i] for i in train_idx]
    }
    test_dict = {
        "data": test_data, 
        "columns": grouped_dict["columns"], 
        "group_ids": [group_ids[i] for i in test_idx]
    }
    
    with open(train_file_path, "wb") as f:
        pickle.dump(train_dict, f)
    with open(test_file_path, "wb") as f:
        pickle.dump(test_dict, f)
    
    print(f"Saved fold {fold+1}:")
    print("  Train participant IDs:", train_dict["group_ids"])
    print("  Test participant IDs:", test_dict["group_ids"])
    print("-" * 50)

# ===== Step 6: Verify No Participant Overlap Between Folds =====
fold_files = [f"train_2d_fold{i}.pkl" for i in range(1, 6)]
fold_participants = {}

for file in fold_files:
    with open(file, "rb") as f:
        fold_dict = pickle.load(f)
    participant_ids = set(fold_dict["group_ids"])
    fold_participants[file] = participant_ids
    print(f"{file} has participant IDs:", participant_ids)

print("=" * 50)
for i in range(len(fold_files)):
    for j in range(i + 1, len(fold_files)):
        common_ids = fold_participants[fold_files[i]].intersection(fold_participants[fold_files[j]])
        print(f"Common participants between {fold_files[i]} and {fold_files[j]}: {common_ids}")
# Out:
# === Original Data ===
# Total rows: 5351
# Unique participant_ids (raw): ['combined_10' 'combined_17' 'combined_16' 'combined_11' 'combined_12'
#  'combined_13' 'combined_14' 'combined_18' 'combined_20' 'combined_200'
#  'combined_21' 'combined_22' 'combined_23' 'combined_24' 'combined_25'
#  'combined_26' 'combined_27' 'combined_28' 'combined_29' 'combined_30'
#  'combined_300' 'combined_31' 'combined_32' 'combined_33' 'combined_34'
#  'combined_35' 'combined_36' 'combined_37' 'combined_38' 'combined_39'
#  'combined_40' 'combined_41' 'combined_42' 'combined_43']
# Counts per participant:
#  participant_id
# combined_18     177
# combined_12     176
# combined_30     175
# combined_16     174
# combined_20     172
# combined_24     172
# combined_13     172
# combined_32     170
# combined_36     170
# combined_27     170
# combined_31     170
# combined_37     169
# combined_35     169
# combined_41     169
# combined_38     169
# combined_26     168
# combined_300    168
# combined_25     168
# combined_11     166
# combined_40     165
# combined_21     165
# combined_22     164
# combined_34     164
# combined_23     164
# combined_33     162
# combined_14     161
# combined_42     159
# combined_10     152
# combined_43     148
# combined_28     127
# combined_29     112
# combined_17      89
# combined_39      88
# combined_200     87
# Name: count, dtype: int64
# --------------------------------------------------
# Grouping participant: combined_10 with 152 rows
# Grouping participant: combined_11 with 166 rows
# Grouping participant: combined_12 with 176 rows
# Grouping participant: combined_13 with 172 rows
# Grouping participant: combined_14 with 161 rows
# Grouping participant: combined_16 with 174 rows
# Grouping participant: combined_17 with 89 rows
# Grouping participant: combined_18 with 177 rows
# Grouping participant: combined_20 with 172 rows
# Grouping participant: combined_200 with 87 rows
# Grouping participant: combined_21 with 165 rows
# Grouping participant: combined_22 with 164 rows
# Grouping participant: combined_23 with 164 rows
# Grouping participant: combined_24 with 172 rows
# Grouping participant: combined_25 with 168 rows
# Grouping participant: combined_26 with 168 rows
# Grouping participant: combined_27 with 170 rows
# Grouping participant: combined_28 with 127 rows
# Grouping participant: combined_29 with 112 rows
# Grouping participant: combined_30 with 175 rows
# Grouping participant: combined_300 with 168 rows
# Grouping participant: combined_31 with 170 rows
# Grouping participant: combined_32 with 170 rows
# Grouping participant: combined_33 with 162 rows
# Grouping participant: combined_34 with 164 rows
# Grouping participant: combined_35 with 169 rows
# Grouping participant: combined_36 with 170 rows
# Grouping participant: combined_37 with 169 rows
# Grouping participant: combined_38 with 169 rows
# Grouping participant: combined_39 with 88 rows
# Grouping participant: combined_40 with 165 rows
# Grouping participant: combined_41 with 169 rows
# Grouping participant: combined_42 with 159 rows
# Grouping participant: combined_43 with 148 rows
# Total groups formed: 34
# Unique group_ids: {'combined_21', 'combined_10', 'combined_14', 'combined_18', 'combined_40', 'combined_24', 'combined_23', 'combined_34', 'combined_38', 'combined_43', 'combined_20', 'combined_17', 'combined_300', 'combined_41', 'combined_30', 'combined_26', 'combined_39', 'combined_16', 'combined_200', 'combined_25', 'combined_35', 'combined_27', 'combined_28', 'combined_12', 'combined_31', 'combined_42', 'combined_36', 'combined_29', 'combined_37', 'combined_13', 'combined_32', 'combined_33', 'combined_22', 'combined_11'}
# --------------------------------------------------
# Grouped data saved to processed_2d_data_new.pkl
# --------------------------------------------------
# === Processed Data Info ===
# Number of unique participants: 34
# List of participant IDs: ['combined_10', 'combined_11', 'combined_12', 'combined_13', 'combined_14', 'combined_16', 'combined_17', 'combined_18', 'combined_20', 'combined_200', 'combined_21', 'combined_22', 'combined_23', 'combined_24', 'combined_25', 'combined_26', 'combined_27', 'combined_28', 'combined_29', 'combined_30', 'combined_300', 'combined_31', 'combined_32', 'combined_33', 'combined_34', 'combined_35', 'combined_36', 'combined_37', 'combined_38', 'combined_39', 'combined_40', 'combined_41', 'combined_42', 'combined_43']
# --------------------------------------------------
# Fold 1:
#   Train indices: [ 0  1  2  4  5  6  7  9 10 11 12 14 15 16 17 19 20 21 22 24 25 26 27 29
#  30 31 32]
#   Test indices: [ 3  8 13 18 23 28 33]
#   Train participant IDs: ['combined_10', 'combined_11', 'combined_12', 'combined_14', 'combined_16', 'combined_17', 'combined_18', 'combined_200', 'combined_21', 'combined_22', 'combined_23', 'combined_25', 'combined_26', 'combined_27', 'combined_28', 'combined_30', 'combined_300', 'combined_31', 'combined_32', 'combined_34', 'combined_35', 'combined_36', 'combined_37', 'combined_39', 'combined_40', 'combined_41', 'combined_42']
#   Test participant IDs: ['combined_13', 'combined_20', 'combined_24', 'combined_29', 'combined_33', 'combined_38', 'combined_43']
# ------------------------------
# Fold 2:
#   Train indices: [ 0  1  3  4  5  6  8  9 10 11 13 14 15 16 18 19 20 21 23 24 25 26 28 29
#  30 31 33]
#   Test indices: [ 2  7 12 17 22 27 32]
#   Train participant IDs: ['combined_10', 'combined_11', 'combined_13', 'combined_14', 'combined_16', 'combined_17', 'combined_20', 'combined_200', 'combined_21', 'combined_22', 'combined_24', 'combined_25', 'combined_26', 'combined_27', 'combined_29', 'combined_30', 'combined_300', 'combined_31', 'combined_33', 'combined_34', 'combined_35', 'combined_36', 'combined_38', 'combined_39', 'combined_40', 'combined_41', 'combined_43']
#   Test participant IDs: ['combined_12', 'combined_18', 'combined_23', 'combined_28', 'combined_32', 'combined_37', 'combined_42']
# ------------------------------
# Fold 3:
#   Train indices: [ 0  2  3  4  5  7  8  9 10 12 13 14 15 17 18 19 20 22 23 24 25 27 28 29
#  30 32 33]
#   Test indices: [ 1  6 11 16 21 26 31]
#   Train participant IDs: ['combined_10', 'combined_12', 'combined_13', 'combined_14', 'combined_16', 'combined_18', 'combined_20', 'combined_200', 'combined_21', 'combined_23', 'combined_24', 'combined_25', 'combined_26', 'combined_28', 'combined_29', 'combined_30', 'combined_300', 'combined_32', 'combined_33', 'combined_34', 'combined_35', 'combined_37', 'combined_38', 'combined_39', 'combined_40', 'combined_42', 'combined_43']
#   Test participant IDs: ['combined_11', 'combined_17', 'combined_22', 'combined_27', 'combined_31', 'combined_36', 'combined_41']
# ------------------------------
# Fold 4:
#   Train indices: [ 1  2  3  4  6  7  8  9 11 12 13 14 16 17 18 19 21 22 23 24 26 27 28 29
#  31 32 33]
#   Test indices: [ 0  5 10 15 20 25 30]
#   Train participant IDs: ['combined_11', 'combined_12', 'combined_13', 'combined_14', 'combined_17', 'combined_18', 'combined_20', 'combined_200', 'combined_22', 'combined_23', 'combined_24', 'combined_25', 'combined_27', 'combined_28', 'combined_29', 'combined_30', 'combined_31', 'combined_32', 'combined_33', 'combined_34', 'combined_36', 'combined_37', 'combined_38', 'combined_39', 'combined_41', 'combined_42', 'combined_43']
#   Test participant IDs: ['combined_10', 'combined_16', 'combined_21', 'combined_26', 'combined_300', 'combined_35', 'combined_40']
# ------------------------------
# Fold 5:
#   Train indices: [ 0  1  2  3  5  6  7  8 10 11 12 13 15 16 17 18 20 21 22 23 25 26 27 28
#  30 31 32 33]
#   Test indices: [ 4  9 14 19 24 29]
#   Train participant IDs: ['combined_10', 'combined_11', 'combined_12', 'combined_13', 'combined_16', 'combined_17', 'combined_18', 'combined_20', 'combined_21', 'combined_22', 'combined_23', 'combined_24', 'combined_26', 'combined_27', 'combined_28', 'combined_29', 'combined_300', 'combined_31', 'combined_32', 'combined_33', 'combined_35', 'combined_36', 'combined_37', 'combined_38', 'combined_40', 'combined_41', 'combined_42', 'combined_43']
#   Test participant IDs: ['combined_14', 'combined_200', 'combined_25', 'combined_30', 'combined_34', 'combined_39']
# ------------------------------
# Saved fold 1:
#   Train participant IDs: ['combined_10', 'combined_11', 'combined_12', 'combined_14', 'combined_16', 'combined_17', 'combined_18', 'combined_200', 'combined_21', 'combined_22', 'combined_23', 'combined_25', 'combined_26', 'combined_27', 'combined_28', 'combined_30', 'combined_300', 'combined_31', 'combined_32', 'combined_34', 'combined_35', 'combined_36', 'combined_37', 'combined_39', 'combined_40', 'combined_41', 'combined_42']
#   Test participant IDs: ['combined_13', 'combined_20', 'combined_24', 'combined_29', 'combined_33', 'combined_38', 'combined_43']
# --------------------------------------------------
# Saved fold 2:
#   Train participant IDs: ['combined_10', 'combined_11', 'combined_13', 'combined_14', 'combined_16', 'combined_17', 'combined_20', 'combined_200', 'combined_21', 'combined_22', 'combined_24', 'combined_25', 'combined_26', 'combined_27', 'combined_29', 'combined_30', 'combined_300', 'combined_31', 'combined_33', 'combined_34', 'combined_35', 'combined_36', 'combined_38', 'combined_39', 'combined_40', 'combined_41', 'combined_43']
#   Test participant IDs: ['combined_12', 'combined_18', 'combined_23', 'combined_28', 'combined_32', 'combined_37', 'combined_42']
# --------------------------------------------------
# Saved fold 3:
#   Train participant IDs: ['combined_10', 'combined_12', 'combined_13', 'combined_14', 'combined_16', 'combined_18', 'combined_20', 'combined_200', 'combined_21', 'combined_23', 'combined_24', 'combined_25', 'combined_26', 'combined_28', 'combined_29', 'combined_30', 'combined_300', 'combined_32', 'combined_33', 'combined_34', 'combined_35', 'combined_37', 'combined_38', 'combined_39', 'combined_40', 'combined_42', 'combined_43']
#   Test participant IDs: ['combined_11', 'combined_17', 'combined_22', 'combined_27', 'combined_31', 'combined_36', 'combined_41']
# --------------------------------------------------
# Saved fold 4:
#   Train participant IDs: ['combined_11', 'combined_12', 'combined_13', 'combined_14', 'combined_17', 'combined_18', 'combined_20', 'combined_200', 'combined_22', 'combined_23', 'combined_24', 'combined_25', 'combined_27', 'combined_28', 'combined_29', 'combined_30', 'combined_31', 'combined_32', 'combined_33', 'combined_34', 'combined_36', 'combined_37', 'combined_38', 'combined_39', 'combined_41', 'combined_42', 'combined_43']
#   Test participant IDs: ['combined_10', 'combined_16', 'combined_21', 'combined_26', 'combined_300', 'combined_35', 'combined_40']
# --------------------------------------------------
# Saved fold 5:
#   Train participant IDs: ['combined_10', 'combined_11', 'combined_12', 'combined_13', 'combined_16', 'combined_17', 'combined_18', 'combined_20', 'combined_21', 'combined_22', 'combined_23', 'combined_24', 'combined_26', 'combined_27', 'combined_28', 'combined_29', 'combined_300', 'combined_31', 'combined_32', 'combined_33', 'combined_35', 'combined_36', 'combined_37', 'combined_38', 'combined_40', 'combined_41', 'combined_42', 'combined_43']
#   Test participant IDs: ['combined_14', 'combined_200', 'combined_25', 'combined_30', 'combined_34', 'combined_39']
# --------------------------------------------------
# train_2d_fold1.pkl has participant IDs: {'combined_21', 'combined_10', 'combined_14', 'combined_18', 'combined_40', 'combined_23', 'combined_34', 'combined_17', 'combined_300', 'combined_41', 'combined_30', 'combined_26', 'combined_39', 'combined_16', 'combined_200', 'combined_25', 'combined_35', 'combined_27', 'combined_28', 'combined_12', 'combined_31', 'combined_42', 'combined_36', 'combined_37', 'combined_32', 'combined_22', 'combined_11'}
# train_2d_fold2.pkl has participant IDs: {'combined_21', 'combined_10', 'combined_14', 'combined_40', 'combined_24', 'combined_34', 'combined_38', 'combined_43', 'combined_20', 'combined_17', 'combined_300', 'combined_41', 'combined_30', 'combined_26', 'combined_39', 'combined_16', 'combined_200', 'combined_25', 'combined_35', 'combined_27', 'combined_31', 'combined_36', 'combined_29', 'combined_13', 'combined_33', 'combined_22', 'combined_11'}
# train_2d_fold3.pkl has participant IDs: {'combined_21', 'combined_10', 'combined_14', 'combined_18', 'combined_40', 'combined_24', 'combined_23', 'combined_34', 'combined_38', 'combined_43', 'combined_20', 'combined_300', 'combined_30', 'combined_26', 'combined_39', 'combined_16', 'combined_200', 'combined_25', 'combined_35', 'combined_28', 'combined_12', 'combined_42', 'combined_29', 'combined_37', 'combined_13', 'combined_32', 'combined_33'}
# train_2d_fold4.pkl has participant IDs: {'combined_14', 'combined_18', 'combined_24', 'combined_23', 'combined_34', 'combined_38', 'combined_43', 'combined_20', 'combined_17', 'combined_41', 'combined_30', 'combined_39', 'combined_200', 'combined_25', 'combined_27', 'combined_28', 'combined_12', 'combined_31', 'combined_42', 'combined_36', 'combined_29', 'combined_37', 'combined_13', 'combined_32', 'combined_33', 'combined_22', 'combined_11'}
# train_2d_fold5.pkl has participant IDs: {'combined_21', 'combined_10', 'combined_18', 'combined_40', 'combined_24', 'combined_23', 'combined_38', 'combined_43', 'combined_20', 'combined_17', 'combined_300', 'combined_41', 'combined_26', 'combined_16', 'combined_35', 'combined_27', 'combined_28', 'combined_12', 'combined_31', 'combined_42', 'combined_36', 'combined_29', 'combined_37', 'combined_13', 'combined_32', 'combined_33', 'combined_22', 'combined_11'}
# ==================================================
# Common participants between train_2d_fold1.pkl and train_2d_fold2.pkl: {'combined_21', 'combined_10', 'combined_14', 'combined_40', 'combined_34', 'combined_17', 'combined_300', 'combined_41', 'combined_30', 'combined_26', 'combined_39', 'combined_16', 'combined_200', 'combined_25', 'combined_35', 'combined_27', 'combined_31', 'combined_36', 'combined_22', 'combined_11'}
# Common participants between train_2d_fold1.pkl and train_2d_fold3.pkl: {'combined_21', 'combined_10', 'combined_14', 'combined_18', 'combined_40', 'combined_23', 'combined_34', 'combined_300', 'combined_30', 'combined_26', 'combined_39', 'combined_16', 'combined_200', 'combined_25', 'combined_35', 'combined_12', 'combined_28', 'combined_42', 'combined_37', 'combined_32'}
# Common participants between train_2d_fold1.pkl and train_2d_fold4.pkl: {'combined_14', 'combined_18', 'combined_23', 'combined_34', 'combined_17', 'combined_41', 'combined_30', 'combined_39', 'combined_200', 'combined_25', 'combined_12', 'combined_28', 'combined_27', 'combined_31', 'combined_42', 'combined_36', 'combined_37', 'combined_32', 'combined_22', 'combined_11'}
# Common participants between train_2d_fold1.pkl and train_2d_fold5.pkl: {'combined_21', 'combined_10', 'combined_18', 'combined_40', 'combined_23', 'combined_17', 'combined_300', 'combined_41', 'combined_26', 'combined_16', 'combined_35', 'combined_12', 'combined_28', 'combined_27', 'combined_31', 'combined_42', 'combined_36', 'combined_37', 'combined_32', 'combined_22', 'combined_11'}
# Common participants between train_2d_fold2.pkl and train_2d_fold3.pkl: {'combined_21', 'combined_10', 'combined_14', 'combined_40', 'combined_43', 'combined_38', 'combined_24', 'combined_34', 'combined_20', 'combined_300', 'combined_30', 'combined_26', 'combined_39', 'combined_16', 'combined_200', 'combined_25', 'combined_35', 'combined_29', 'combined_13', 'combined_33'}
# Common participants between train_2d_fold2.pkl and train_2d_fold4.pkl: {'combined_14', 'combined_43', 'combined_34', 'combined_24', 'combined_38', 'combined_20', 'combined_17', 'combined_41', 'combined_30', 'combined_39', 'combined_200', 'combined_25', 'combined_27', 'combined_31', 'combined_36', 'combined_29', 'combined_13', 'combined_33', 'combined_22', 'combined_11'}
# Common participants between train_2d_fold2.pkl and train_2d_fold5.pkl: {'combined_21', 'combined_10', 'combined_40', 'combined_43', 'combined_24', 'combined_38', 'combined_20', 'combined_17', 'combined_300', 'combined_41', 'combined_26', 'combined_16', 'combined_35', 'combined_27', 'combined_31', 'combined_36', 'combined_29', 'combined_13', 'combined_33', 'combined_22', 'combined_11'}
# Common participants between train_2d_fold3.pkl and train_2d_fold4.pkl: {'combined_14', 'combined_18', 'combined_23', 'combined_38', 'combined_43', 'combined_24', 'combined_34', 'combined_20', 'combined_30', 'combined_39', 'combined_200', 'combined_25', 'combined_12', 'combined_28', 'combined_42', 'combined_29', 'combined_37', 'combined_13', 'combined_32', 'combined_33'}
# Common participants between train_2d_fold3.pkl and train_2d_fold5.pkl: {'combined_21', 'combined_10', 'combined_18', 'combined_40', 'combined_23', 'combined_43', 'combined_24', 'combined_38', 'combined_20', 'combined_300', 'combined_26', 'combined_16', 'combined_35', 'combined_12', 'combined_28', 'combined_42', 'combined_29', 'combined_37', 'combined_13', 'combined_32', 'combined_33'}
# Common participants between train_2d_fold4.pkl and train_2d_fold5.pkl: {'combined_18', 'combined_23', 'combined_24', 'combined_43', 'combined_38', 'combined_20', 'combined_17', 'combined_41', 'combined_12', 'combined_28', 'combined_27', 'combined_31', 'combined_42', 'combined_36', 'combined_29', 'combined_37', 'combined_13', 'combined_32', 'combined_33', 'combined_22', 'combined_11'}

# %%
for fold, (train_idx, test_idx) in enumerate(gkf.split(data, groups=group_ids)):
    train_group_ids = [group_ids[i] for i in train_idx]
    test_group_ids = [group_ids[i] for i in test_idx]
    
    # Check that there's no overlap within this fold:
    assert set(train_group_ids).isdisjoint(set(test_group_ids)), f"Leakage found in fold {fold+1}!"
    
    print(f"Fold {fold+1} - Train IDs: {train_group_ids}")
    print(f"Fold {fold+1} - Test IDs: {test_group_ids}")
# Out:
# Fold 1 - Train IDs: ['combined_10', 'combined_11', 'combined_12', 'combined_14', 'combined_16', 'combined_17', 'combined_18', 'combined_200', 'combined_21', 'combined_22', 'combined_23', 'combined_25', 'combined_26', 'combined_27', 'combined_28', 'combined_30', 'combined_300', 'combined_31', 'combined_32', 'combined_34', 'combined_35', 'combined_36', 'combined_37', 'combined_39', 'combined_40', 'combined_41', 'combined_42']
# Fold 1 - Test IDs: ['combined_13', 'combined_20', 'combined_24', 'combined_29', 'combined_33', 'combined_38', 'combined_43']
# Fold 2 - Train IDs: ['combined_10', 'combined_11', 'combined_13', 'combined_14', 'combined_16', 'combined_17', 'combined_20', 'combined_200', 'combined_21', 'combined_22', 'combined_24', 'combined_25', 'combined_26', 'combined_27', 'combined_29', 'combined_30', 'combined_300', 'combined_31', 'combined_33', 'combined_34', 'combined_35', 'combined_36', 'combined_38', 'combined_39', 'combined_40', 'combined_41', 'combined_43']
# Fold 2 - Test IDs: ['combined_12', 'combined_18', 'combined_23', 'combined_28', 'combined_32', 'combined_37', 'combined_42']
# Fold 3 - Train IDs: ['combined_10', 'combined_12', 'combined_13', 'combined_14', 'combined_16', 'combined_18', 'combined_20', 'combined_200', 'combined_21', 'combined_23', 'combined_24', 'combined_25', 'combined_26', 'combined_28', 'combined_29', 'combined_30', 'combined_300', 'combined_32', 'combined_33', 'combined_34', 'combined_35', 'combined_37', 'combined_38', 'combined_39', 'combined_40', 'combined_42', 'combined_43']
# Fold 3 - Test IDs: ['combined_11', 'combined_17', 'combined_22', 'combined_27', 'combined_31', 'combined_36', 'combined_41']
# Fold 4 - Train IDs: ['combined_11', 'combined_12', 'combined_13', 'combined_14', 'combined_17', 'combined_18', 'combined_20', 'combined_200', 'combined_22', 'combined_23', 'combined_24', 'combined_25', 'combined_27', 'combined_28', 'combined_29', 'combined_30', 'combined_31', 'combined_32', 'combined_33', 'combined_34', 'combined_36', 'combined_37', 'combined_38', 'combined_39', 'combined_41', 'combined_42', 'combined_43']
# Fold 4 - Test IDs: ['combined_10', 'combined_16', 'combined_21', 'combined_26', 'combined_300', 'combined_35', 'combined_40']
# Fold 5 - Train IDs: ['combined_10', 'combined_11', 'combined_12', 'combined_13', 'combined_16', 'combined_17', 'combined_18', 'combined_20', 'combined_21', 'combined_22', 'combined_23', 'combined_24', 'combined_26', 'combined_27', 'combined_28', 'combined_29', 'combined_300', 'combined_31', 'combined_32', 'combined_33', 'combined_35', 'combined_36', 'combined_37', 'combined_38', 'combined_40', 'combined_41', 'combined_42', 'combined_43']
# Fold 5 - Test IDs: ['combined_14', 'combined_200', 'combined_25', 'combined_30', 'combined_34', 'combined_39']
